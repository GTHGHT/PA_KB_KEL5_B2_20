# %% [markdown]
# ### Import Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### Load The Dataset

# %%
data = pd.read_csv('cleaned_twitter.csv')

# %% [markdown]
# ### EDA (Exploratory Data Analysis)
# - Menggunakan Dataset yang telah dibersihkan

# %%
data.info() #informasi dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12308 entries, 0 to 12307
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sentimen  12308 non-null  float64
#  1   Tweet     12008 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 192.4+ KB

# %%
data.head() #melihat 5 data teratas
# Out:
#    sentimen                                              Tweet
# 0       0.0  barusan liat tulisan di belakang truk rela inj...
# 1       0.0  her itu lho miss kevin sama keven rebutan gimb...
# 2       0.0     iya rep gatau saya masih kelas sd ehh di block
# 3       0.0     saya mohon tepatilah janjimu penantiancintaeps
# 4       0.0  bukan beria nk kahwin sbb gatal celah kangkang...

# %%
data.describe() #Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.
# Out:
#            sentimen
# count  12308.000000
# mean       0.907377
# std        0.874436
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        2.000000

# %%
data.shape #meihat dimensi data
# Out:
# (12308, 2)

# %%
data.isnull().sum().sum() #melihat data bernilai null atau kosong
# Out:
# 300

# %%
data.duplicated().sum() #melihat record duplicated
# Out:
# 822

# %%
data.value_counts() #melihat record unik
# Out:
# sentimen  Tweet
# 2.0       kalau tak bersungguh nak jaga saya boleh je berhenti berpura saya boleh jaga diri saya tanpa memaksa kamu kamu tak perl    10
#           hati saya kecewa saya sedih saya saya seorang je tahu orang lain tak tahu                                                   7
# 0.0       ni nak femes je sebenarnya                                                                                                  7
#           giveaway diadakan dalam rangka bday guanlin mau tambah teman monbebe amp nctzen                                             6
#           amin ustazah saya pening kepala me takpelah awak tulis je apa yang awak laratampai masa saya suruh hantar buku tara         6
#                                                                                                                                      ..
#           saya selalu menyempatkan sore saya untuk menatap langit berlama lama disana melihat langit membuat saya merasa lebih        1
# ...

# %% [markdown]
# ### Visualisasi
# - WordCloud Netral Label

# %%
plt.figure(figsize=(45,45))
netral_label = data['Tweet'][data["sentimen"] == 0.0]
netral_wordcloud = WordCloud(stopwords=STOPWORDS ,max_words=150, max_font_size=50, background_color='white').generate(''.join(map(str, netral_label)))

plt.subplot(1, 3, 2)
plt.title("Netral Label")
plt.imshow(netral_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# - WordCloud Positif Label

# %%
plt.figure(figsize=(45,45))
positif_label = data['Tweet'][data['sentimen'] == 1.0]
positif_wordcloud = WordCloud(stopwords=STOPWORDS, max_words=150, max_font_size=50, background_color='white').generate(str(positif_label))

plt.subplot(1, 3, 2)
plt.title("Positif Label")
plt.imshow(positif_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# - WordCloud Negatif Label

# %%
plt.figure(figsize=(45,45))
negatif_label = data['Tweet'][data['sentimen'] == 2.0]
negatif_wordcloud = WordCloud(stopwords=STOPWORDS, max_words=150, max_font_size=50, background_color='white').generate(str(negatif_label))

plt.subplot(1, 3, 2)
plt.title("Negatif Label")
plt.imshow(negatif_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# - Pie Chart Sentimen Label

# %%
data_pie = data['sentimen'].value_counts()
plt.figure(figsize =(10,10))
plt.pie(data_pie, startangle=90, autopct='%.1f%%')
plt.title("Sentimen label")
plt.show()

# %%
data['sentimen'].value_counts()
# Out:
# 0.0    5328
# 2.0    4188
# 1.0    2792
# Name: sentimen, dtype: int64
